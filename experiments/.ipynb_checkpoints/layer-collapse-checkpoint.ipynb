# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# Python version: 3.6

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import copy
import numpy as np
from torchvision import datasets, transforms
import torch

from utils.sampling import mnist_iid, mnist_noniid, cifar_iid
from utils.options import args_parser
from models.Update import LocalUpdate
from models.Nets import MLP, CNNMnist, CNNCifar
from models.Fed import FedAvg
from models.test import test_img
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 13
#      10 from torchvision import datasets, transforms
#      11 import torch
# ---> 13 from utils.sampling import mnist_iid, mnist_noniid, cifar_iid
#      14 from utils.options import args_parser
#      15 from models.Update import LocalUpdate
#
# ModuleNotFoundError: No module named 'utils'

# %% [markdown]
# ### Seed settings
# - If you want the seed to be set manually, uncomment and set the seed value in these files:
# - also change uncomment the lines with `torch.backends.cudnn.deterministic = True`
# 1. utils/sampling.py
# 2. main_fed.py
# 3. models/Nets.py

# %% [markdown]
# ## Run the layer-colapse.py
# - This command is equivalent to running it from the console
# - Results are saved in federated-learning/save/test.png

# %%
import sys
sys.path.append('../')
# %run ../layer-collapse.py --dataset mnist --iid --num_channels 1 --model mlp --epochs 1 --gpu -1 --num_users 100 --frac 0.01 --compression 10 --prune_epochs 100 --pruner mag
# Out:
# MLP(
#   (layer_input): Linear(in_features=784, out_features=200, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
#   (layer_hidden): Linear(in_features=200, out_features=10, bias=True)
# )
# synflow
# 158800.0 158800 0.0
# Round   0, Average loss 1.410
# Training accuracy: 76.65
# Testing accuracy: 77.49
# MLP(
#   (layer_input): Linear(in_features=784, out_features=200, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
#   (layer_hidden): Linear(in_features=200, out_features=10, bias=True)
# )
# mag
# 158800.0 158800 0.0
# Round   0, Average loss 0.566
# Training accuracy: 84.29
# Testing accuracy: 85.48
# MLP(
#   (layer_input): Linear(in_features=784, out_features=200, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
#   (layer_hidden): Linear(in_features=200, out_features=10, bias=True)
# )
# synflow
# 83370.0 158800 69500.19755977257
# Round   0, Average loss 1.288
# Training accuracy: 78.21
# ...

# %% [markdown]
# ## Testing plots
#
# - The code below is for testing plots from the results printed by manually copying them.
# - To plot the results directly, uncomment the `plt.show()` line
# - To save the results, uncomment the `plt.savefig()` line

# %%
import matplotlib.pyplot as plt
import torch
y = {}
iters = 25
alphas = [i/4 for i in range(iters)]
y['synflow'] = [torch.tensor(78.5500), torch.tensor(76.8500), torch.tensor(79.3100), torch.tensor(83.1500), torch.tensor(84.1600), torch.tensor(85.), torch.tensor(85.1000), torch.tensor(85.5700), torch.tensor(85.9800), torch.tensor(86.1500), torch.tensor(85.7300), torch.tensor(86.0900), torch.tensor(85.2800), torch.tensor(84.4400), torch.tensor(81.0600), torch.tensor(80.3000), torch.tensor(79.7700), torch.tensor(78.8100), torch.tensor(74.9300), torch.tensor(73.6800), torch.tensor(69.5600), torch.tensor(67.7200), torch.tensor(67.7200), torch.tensor(67.7200), torch.tensor(67.7200)]
y['mag'] = [torch.tensor(86.8800), torch.tensor(86.7500), torch.tensor(86.8300), torch.tensor(86.7400), torch.tensor(86.9100), torch.tensor(86.7400), torch.tensor(86.5100), torch.tensor(86.4600), torch.tensor(85.9800), torch.tensor(85.0200), torch.tensor(84.3300), torch.tensor(84.6700), torch.tensor(84.5800), torch.tensor(83.6300), torch.tensor(78.3700), torch.tensor(76.9900), torch.tensor(67.8800), torch.tensor(68.3400), torch.tensor(69.), torch.tensor(62.6500), torch.tensor(62.6500), torch.tensor(62.6500), torch.tensor(62.6500), torch.tensor(62.6500), torch.tensor(62.6500)]
x_vals = [10**alpha for alpha in alphas]
plt.figure()
plt.xscale('log')
plt.plot(x_vals, y['synflow'], label='Synflow', linestyle='-', marker='o', color='r')
plt.plot(x_vals, y['mag'], label='Mag', linestyle='-', marker='o', color='b')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Synflow vs Mag')

# Add legend
plt.legend()

# Save plot
# plt.savefig('../save/test-plot.png'.format())

# Show plot
plt.show()
